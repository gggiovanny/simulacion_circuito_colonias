# %%
import traffic_generator as tg
import numpy as np
import matplotlib.pyplot as plt

# %%
graphdata = tg.genPeakProbs(50, 'medium', graphmode=True)
plt.plot(graphdata['x'], graphdata['y'])

# %%
graphdata = tg.genUniformProbs(50, 'medium', graphmode=True)
plt.plot(graphdata['x'], graphdata['y'])

# %%
tg.genPeakProbs(50, 'medium')
# Out:
# array([0.41020121, 0.41665823, 0.42294156, 0.42904035, 0.43494394,
#        0.44064191, 0.44612411, 0.45138068, 0.45640207, 0.46117911,
#        0.46570298, 0.46996529, 0.47395807, 0.47767381, 0.4811055 ,
#        0.4842466 , 0.48709112, 0.48963361, 0.49186917, 0.49379349,
#        0.49540284, 0.49669409, 0.49766474, 0.49831289, 0.49863729,
#        0.49863729, 0.49831289, 0.49766474, 0.49669409, 0.49540284,
#        0.49379349, 0.49186917, 0.48963361, 0.48709112, 0.4842466 ,
#        0.4811055 , 0.47767381, 0.47395807, 0.46996529, 0.46570298,
#        0.46117911, 0.45640207, 0.45138068, 0.44612411, 0.44064191,
#        0.43494394, 0.42904035, 0.42294156, 0.41665823, 0.41020121])

# %%
tg.genUniformProbs(50, 'medium')
# Out:
# array([0.52474711, 0.28770171, 0.31579381, 0.01043382, 0.1201586 ,
#        0.24835131, 0.39344407, 0.22656161, 0.2307885 , 0.10573222,
#        0.14371479, 0.24619962, 0.54958834, 0.43137139, 0.11287066,
#        0.21721786, 0.19029705, 0.36911905, 0.12022885, 0.47648231,
#        0.14308532, 0.31152177, 0.30018498, 0.23669677, 0.21442812,
#        0.55584682, 0.20253788, 0.17480991, 0.29164203, 0.18933774,
#        0.02520999, 0.28698981, 0.26401274, 0.4304009 , 0.35138408,
#        0.28128096, 0.46337296, 0.00785187, 0.34615016, 0.59701034,
#        0.23697069, 0.38628975, 0.05999352, 0.00533111, 0.35515935,
#        0.56335888, 0.38214705, 0.44613585, 0.11087817, 0.09228685])
